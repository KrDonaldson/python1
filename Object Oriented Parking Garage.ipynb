# %% [markdown]
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
#
# Your parking garage class should have the following methods:
# - takeTicket
# - This should decrease the amount of tickets available by 1
# - This should decrease the amount of parkingSpaces available by 1
# - payForParking
# - Display an input that waits for an amount from the user and store it in a variable
# - If the payment variable is not empty then (meaning the ticket has been paid) -> display a message to the user that their ticket has been paid and they have 15mins to leave
# - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
# - If the ticket has been paid, display a message of "Thank You, have a nice day"
# - If the ticket has not been paid, display an input prompt for payment
# - Once paid, display message "Thank you, have a nice day!"
# - Update parkingSpaces list to increase by 1 (meaning add to the parkingSpaces list)
# - Update tickets list to increase by 1 (meaning add to the tickets list)
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary
#
# By the end of this project each student should be able to:
# - Explain and/or demonstrate creating classes
# - Explain and/or demonstrate creating class methods
# - Explain and/or demonstrate class instantiation
#
#
# When the project is completed, commit the final changes and submit your GitHub link.

# %%
list(range(1,21))

class ParkingGarage():
    
    tickets = [1,2,3,4,5]
    parkingSpaces = [1,2,3,4,5]
    
    '''
    This Parking Garage class will have tickets and parking spaces. 
    It will have three methods, take a ticket, pay for ticket, and 
    leave the garage. 
    '''
    
    def __init__(self, currentTicket = {}):
        self.currentTicket = currentTicket
    
    def take_ticket(self):
        self.ticket_number = self.tickets.pop(0)
        self.parkingSpaces.pop(0)
        self.currentTicket['Ticket Number']=self.ticket_number
        self.currentTicket.update({ self.ticket_number: { 'paid' : False}})
        print(f'\nPlease take ticket number {self.ticket_number}.')
        print(f'\nTickets currently available: {self.tickets}')
        print(f'Spaces currently available: {self.parkingSpaces}')
    
    def pay_for_ticket(self):
        self.ticket_number = input('What is your ticket number? :')
        self.payment = input('How much will you be paying? :')
        if self.payment:
            self.currentTicket.update({ self.ticket_number: { 'paid' : True}})
            print("Your ticket has been paid. You have 15 minutes to exit the garage.")
            #they have to leave for the tickets and parking spaces to be updated
        
    def leave_garage(self):
        self.ticket_number = int(input('What is your ticket number? :'))
        if self.currentTicket[self.ticket_number]['paid'] == True:
            print ("Thank You, have a nice day")
        else:
            payment = int(input('How much will you be paying? :'))
            if payment:
                self.currentTicket.update({ self.ticket_number: { 'paid' : True}})
                print("Thank you, have a nice day!")
        self.parkingSpaces.append(int(self.ticket_number))
        self.tickets.append(int(self.ticket_number))

myGarage = ParkingGarage()

def make_a_choice():
    while True:
        user_input = input("What would you like to do? Select 1, 2, or 3 \n1.Park \n2.Pay \n3.Leave\n")
    
        if user_input == 'quit':
            return
        #manager override to close out the program 
        
        elif int(user_input) == 1:
            myGarage.take_ticket()

        elif int(user_input) == 2:
            myGarage.pay_for_ticket()

        elif int(user_input) == 3:
            myGarage.leave_garage()

        else: 
            print("Please select a valid option")
            make_a_choice()
        
make_a_choice()
# Out:
# What would you like to do? Select 1, 2, or 3
# 1.Park
# 2.Pay
# 3.Leave
# 1
#
# Please take ticket number 1.
#
# Tickets currently available: [2, 3, 4, 5]
# Spaces currently available: [2, 3, 4, 5]
# What would you like to do? Select 1, 2, or 3
# 1.Park
# 2.Pay
# 3.Leave
# 1
#
# Please take ticket number 2.
#
# Tickets currently available: [3, 4, 5]
# Spaces currently available: [3, 4, 5]
# What would you like to do? Select 1, 2, or 3
# 1.Park
# 2.Pay
# 3.Leave
# quit
